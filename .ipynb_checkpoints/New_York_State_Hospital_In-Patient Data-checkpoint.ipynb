# %%
#pip commands
#!pip install mysql-connector-python

# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#import mysql.connector

# %% [markdown]
# # Data Loading

# %%
#Loading the csv data into Raw_Data DataFrame

Raw_data = pd.read_csv("D:\Learnings\Study Materials\Datasets\Files\Hospital-inpatient-discharges.csv\hospital-inpatient-discharges-sparcs-de-identified-2010-1.csv")
# Out:
# C:\Users\anilkumar.suram\AppData\Local\Temp\ipykernel_14948\2317798945.py:3: DtypeWarning: Columns (1,2,7,11,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   Raw_data = pd.read_csv("D:\Learnings\Study Materials\Datasets\Files\Hospital-inpatient-discharges.csv\hospital-inpatient-discharges-sparcs-de-identified-2010-1.csv")

# %% [markdown]
# # Data Exploration

# %%
#Basic Data Overview 

display(Raw_data.head())

display(Raw_data.info())
# Out:
#    index Health Service Area Hospital County  Operating Certificate Number  \
# 0      0      Capital/Adiron          Albany                      101000.0
# 1      1      Capital/Adiron          Albany                      101000.0
# 2      2      Capital/Adiron          Albany                      101000.0
# 3      3      Capital/Adiron          Albany                      101000.0
# 4      4      Capital/Adiron          Albany                      101000.0
#
#    Facility ID                   Facility Name    Age Group  \
# 0          1.0  Albany Medical Center Hospital     18 to 29
# 1          1.0  Albany Medical Center Hospital     50 to 69
# 2          1.0  Albany Medical Center Hospital  70 or Older
# 3          1.0  Albany Medical Center Hospital  70 or Older
# 4          1.0  Albany Medical Center Hospital  70 or Older
#
#   Zip Code - 3 digits Gender   Race  ... Source of Payment 2  \
# 0                 NaN      F  White  ...            Self-Pay
# 1                 NaN      M  White  ...            Medicare
# 2                 NaN      M  White  ...          Blue Cross
# 3                 NaN      F  White  ...   Insurance Company
# 4                 NaN      F  White  ...   Insurance Company
#
#   Source of Payment 3 Attending Provider License Number  \
# 0                 NaN                            3623.0
# 1          Blue Cross                          216951.0
# 2            Self-Pay                            3076.0
# 3            Self-Pay                          140796.0
# 4            Self-Pay                          170254.0
#
#   Operating Provider License Number  Other Provider License Number  \
# 0                               NaN                            NaN
# 1                          216951.0                            NaN
# 2                               NaN                            NaN
# 3                          140796.0                       170254.0
# 4                          170254.0                       170254.0
#
#    Birth Weight Abortion Edit Indicator  Emergency Department Indicator  \
# 0             0                       N                               Y
# 1             0                       N                               Y
# 2             0                       N                               N
# 3             0                       N                               N
# 4             0                       N                               N
#
#   Total Charges  Total Costs
# 0       4476.23      1672.65
# 1     148612.34     51414.70
# 2      16561.99      4032.49
# 3      13593.51      4947.81
# 4      31962.58     16988.33
#
# [5 rows x 38 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2622133 entries, 0 to 2622132
# Data columns (total 38 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   index                                int64
#  1   Health Service Area                  object
#  2   Hospital County                      object
#  3   Operating Certificate Number         float64
#  4   Facility ID                          float64
#  5   Facility Name                        object
#  6   Age Group                            object
#  7   Zip Code - 3 digits                  object
#  8   Gender                               object
#  9   Race                                 object
#  10  Ethnicity                            object
#  11  Length of Stay                       object
#  12  Type of Admission                    object
#  13  Patient Disposition                  object
#  14  Discharge Year                       int64
#  15  CCS Diagnosis Code                   float64
#  16  CCS Diagnosis Description            object
#  17  CCS Procedure Code                   float64
#  18  CCS Procedure Description            object
#  19  APR DRG Code                         int64
#  20  APR DRG Description                  object
#  21  APR MDC Code                         int64
#  22  APR MDC Description                  object
#  23  APR Severity of Illness Code         int64
#  24  APR Severity of Illness Description  object
#  25  APR Risk of Mortality                object
#  26  APR Medical Surgical Description     object
#  27  Source of Payment 1                  object
#  28  Source of Payment 2                  object
#  29  Source of Payment 3                  object
#  30  Attending Provider License Number    float64
#  31  Operating Provider License Number    float64
#  32  Other Provider License Number        float64
#  33  Birth Weight                         int64
#  34  Abortion Edit Indicator              object
#  35  Emergency Department Indicator       object
#  36  Total Charges                        float64
#  37  Total Costs                          float64
# dtypes: float64(9), int64(6), object(23)
# memory usage: 760.2+ MB
# None

# %%
#Displaying the Columns in the Dataset

Raw_data.columns
# Out:
# Index(['index', 'Health Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Facility ID', 'Facility Name',
#        'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race', 'Ethnicity',
#        'Length of Stay', 'Type of Admission', 'Patient Disposition',
#        'Discharge Year', 'CCS Diagnosis Code', 'CCS Diagnosis Description',
#        'CCS Procedure Code', 'CCS Procedure Description', 'APR DRG Code',
#        'APR DRG Description', 'APR MDC Code', 'APR MDC Description',
#        'APR Severity of Illness Code', 'APR Severity of Illness Description',
#        'APR Risk of Mortality', 'APR Medical Surgical Description',
#        'Source of Payment 1', 'Source of Payment 2', 'Source of Payment 3',
#        'Attending Provider License Number',
#        'Operating Provider License Number', 'Other Provider License Number',
#        'Birth Weight', 'Abortion Edit Indicator',
#        'Emergency Department Indicator', 'Total Charges', 'Total Costs'],
#       dtype='object')

# %%
#Summary Statistics

display(Raw_data.describe())
# Out:
#               index  Operating Certificate Number   Facility ID  \
# count  2.622133e+06                  2.617246e+06  2.617246e+06
# mean   1.311066e+06                  5.019051e+06  1.036953e+03
# std    7.569447e+05                  2.249577e+06  6.448892e+02
# min    0.000000e+00                  1.010000e+05  1.000000e+00
# 25%    6.555330e+05                  2.951001e+06  5.410000e+02
# 50%    1.311066e+06                  5.907002e+06  1.117000e+03
# 75%    1.966599e+06                  7.002002e+06  1.450000e+03
# max    2.622132e+06                  7.004010e+06  9.059000e+03
#
#        Discharge Year  CCS Diagnosis Code  CCS Procedure Code  APR DRG Code  \
# count       2622133.0        2.619860e+06        2.619860e+06  2.622133e+06
# mean           2010.0        1.919431e+02        1.121324e+02  4.069629e+02
# std               0.0        1.565932e+02        8.761224e+01  2.404910e+02
# min            2010.0        1.000000e+00        0.000000e+00  1.000000e+00
# 25%            2010.0        1.060000e+02        0.000000e+00  1.980000e+02
# 50%            2010.0        1.570000e+02        1.240000e+02  3.610000e+02
# 75%            2010.0        2.180000e+02        2.110000e+02  6.400000e+02
# max            2010.0        6.700000e+02        2.310000e+02  9.560000e+02
#
#        APR MDC Code  APR Severity of Illness Code  \
# count  2.622133e+06                  2.622133e+06
# mean   1.016206e+01                  1.948373e+00
# std    5.923678e+00                  8.986120e-01
# min    0.000000e+00                  0.000000e+00
# 25%    5.000000e+00                  1.000000e+00
# 50%    8.000000e+00                  2.000000e+00
# 75%    1.500000e+01                  3.000000e+00
# max    2.500000e+01                  4.000000e+00
#
#        Attending Provider License Number  Operating Provider License Number  \
# count                       2.617246e+06                       1.951315e+06
# mean                        1.266323e+06                       1.569229e+06
# std                         8.226220e+06                       9.379695e+06
# min                         1.000000e+00                       1.000000e+00
# 25%                         1.666590e+05                       1.644990e+05
# 50%                         2.053620e+05                       2.012870e+05
# 75%                         2.335610e+05                       2.305590e+05
# max                         9.100000e+07                       9.100000e+07
#
#        Other Provider License Number  Birth Weight  Total Charges  \
# count                   4.881420e+05  2.622133e+06   2.622133e+06
# mean                    2.213083e+06  3.103701e+02   2.945920e+04
# std                     1.225216e+07  9.769686e+02   5.640021e+04
# min                     1.100000e+01  0.000000e+00   1.000000e-02
# 25%                     1.662850e+05  0.000000e+00   7.900000e+03
# 50%                     2.029570e+05  0.000000e+00   1.567373e+04
# 75%                     2.335750e+05  0.000000e+00   3.172352e+04
# max                     9.100000e+07  9.900000e+03   1.206004e+07
#
#         Total Costs
# count  2.622133e+06
# mean   1.186523e+04
# std    2.727029e+04
# min    0.000000e+00
# 25%    3.290510e+03
# 50%    6.175350e+03
# 75%    1.222803e+04
# max    1.470885e+07

# %%
#Count of the Raw data in each column
Raw_data.count()
# Out:
# index                                  2622133
# Health Service Area                    2617246
# Hospital County                        2617246
# Operating Certificate Number           2617246
# Facility ID                            2617246
# Facility Name                          2622133
# Age Group                              2622133
# Zip Code - 3 digits                    2618932
# Gender                                 2622133
# Race                                   2622133
# Ethnicity                              2622133
# Length of Stay                         2622133
# Type of Admission                      2622133
# Patient Disposition                    2622030
# Discharge Year                         2622133
# CCS Diagnosis Code                     2619860
# CCS Diagnosis Description              2619860
# CCS Procedure Code                     2619860
# CCS Procedure Description              2619860
# APR DRG Code                           2622133
# APR DRG Description                    2622133
# APR MDC Code                           2622133
# APR MDC Description                    2622133
# APR Severity of Illness Code           2622133
# APR Severity of Illness Description    2621892
# APR Risk of Mortality                  2621892
# APR Medical Surgical Description       2622133
# Source of Payment 1                    2622133
# Source of Payment 2                    1811752
# Source of Payment 3                     581292
# Attending Provider License Number      2617246
# Operating Provider License Number      1951315
# Other Provider License Number           488142
# Birth Weight                           2622133
# Abortion Edit Indicator                2622133
# Emergency Department Indicator         2622133
# Total Charges                          2622133
# Total Costs                            2622133
# dtype: int64

# %%
#Identifying the Null values in each column
na_values_In_each_column = Raw_data.isnull().sum()
display(na_values_In_each_column)
# Out:
# index                                        0
# Health Service Area                       4887
# Hospital County                           4887
# Operating Certificate Number              4887
# Facility ID                               4887
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                       3201
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                        103
# Discharge Year                               0
# CCS Diagnosis Code                        2273
# CCS Diagnosis Description                 2273
# CCS Procedure Code                        2273
# CCS Procedure Description                 2273
# APR DRG Code                                 0
# APR DRG Description                          0
# APR MDC Code                                 0
# APR MDC Description                          0
# APR Severity of Illness Code                 0
# APR Severity of Illness Description        241
# APR Risk of Mortality                      241
# APR Medical Surgical Description             0
# Source of Payment 1                          0
# Source of Payment 2                     810381
# Source of Payment 3                    2040841
# Attending Provider License Number         4887
# Operating Provider License Number       670818
# Other Provider License Number          2133991
# Birth Weight                                 0
# Abortion Edit Indicator                      0
# Emergency Department Indicator               0
# Total Charges                                0
# Total Costs                                  0
# dtype: int64

# %%
#Exploring the Categorical Columns

#Gender
display(Raw_data["Gender"].unique())
display(Raw_data["Gender"].value_counts())

#Race
display(Raw_data["Race"].unique())
display(Raw_data["Race"].value_counts())

#Ethinicity
display(Raw_data["Ethnicity"].unique())
display(Raw_data["Ethnicity"].value_counts())
# Out:
# array(['F', 'M', 'U'], dtype=object)
# F    1477671
# M    1144399
# U         63
# Name: Gender, dtype: int64
# array(['White', 'Black/African American', 'Other Race', 'Unknown'],
#       dtype=object)
# White                     1601378
# Black/African American     498561
# Other Race                 493854
# Unknown                     28340
# Name: Race, dtype: int64
# array(['Not Span/Hispanic', 'Spanish/Hispanic', 'Unknown'], dtype=object)
# Not Span/Hispanic    2116780
# Spanish/Hispanic      351609
# Unknown               153744
# Name: Ethnicity, dtype: int64

# %%
#Data Visualization
#Histogram for Numeric data
plt.hist(Raw_data["Total Charges"], bins=5, color = "skyblue")
plt.title("Distribution of Total Charges")
plt.xlabel("Total Charges")
plt.ylabel("Frequency")
plt.show()

# %%
#Data Visualization
#Bar plots for Categorical data
sns.countplot(x='Age Group', data=Raw_data, palette='Set3')
plt.title("Age Group Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
#Grouping and Aggregations
age_charges = Raw_data.groupby("Age Group")["Total Charges"].mean()
display(age_charges)
# Out:
# Age Group
# 0 to 17        17902.255376
# 18 to 29       18407.457158
# 30 to 49       24358.897348
# 50 to 69       36483.566360
# 70 or Older    37190.367251
# Name: Total Charges, dtype: float64

# %% [markdown]
# # Data Cleaning

# %%
#Function to replace space with "_" between words in the column names
def replace_spaces_with_underscores(df):
    column_rename_dict = {col: col.replace(' ', '_') for col in df.columns}
    df = df.rename(columns=column_rename_dict)
    return df

# %%
#Load the Raw_data into new Dataframe
modified_column_names = pd.DataFrame(Raw_data)

#Replace the column names having space within name with an "_"
modified_column_names = replace_spaces_with_underscores(modified_column_names)
display(modified_column_names)
# Out:
#            index Health_Service_Area Hospital_County  \
# 0              0      Capital/Adiron          Albany
# 1              1      Capital/Adiron          Albany
# 2              2      Capital/Adiron          Albany
# 3              3      Capital/Adiron          Albany
# 4              4      Capital/Adiron          Albany
# ...          ...                 ...             ...
# 2622128  2622128                 NaN             NaN
# 2622129  2622129                 NaN             NaN
# 2622130  2622130                 NaN             NaN
# 2622131  2622131                 NaN             NaN
# 2622132  2622132                 NaN             NaN
#
#          Operating_Certificate_Number  Facility_ID  \
# 0                            101000.0          1.0
# 1                            101000.0          1.0
# 2                            101000.0          1.0
# 3                            101000.0          1.0
# 4                            101000.0          1.0
# ...                               ...          ...
# 2622128                           NaN          NaN
# 2622129                           NaN          NaN
# 2622130                           NaN          NaN
# 2622131                           NaN          NaN
# 2622132                           NaN          NaN
#
#                                     Facility_Name    Age_Group  \
# 0                  Albany Medical Center Hospital     18 to 29
# 1                  Albany Medical Center Hospital     50 to 69
# 2                  Albany Medical Center Hospital  70 or Older
# 3                  Albany Medical Center Hospital  70 or Older
# 4                  Albany Medical Center Hospital  70 or Older
# ...                                           ...          ...
# 2622128  Abortion Record - Facility Name Redacted     30 to 49
# 2622129  Abortion Record - Facility Name Redacted     30 to 49
# 2622130  Abortion Record - Facility Name Redacted     30 to 49
# 2622131  Abortion Record - Facility Name Redacted     30 to 49
# 2622132  Abortion Record - Facility Name Redacted     30 to 49
#
#         Zip_Code_-_3_digits Gender        Race  ... Source_of_Payment_2  \
# 0                       NaN      F       White  ...            Self-Pay
# 1                       NaN      M       White  ...            Medicare
# 2                       NaN      M       White  ...          Blue Cross
# 3                       NaN      F       White  ...   Insurance Company
# 4                       NaN      F       White  ...   Insurance Company
# ...                     ...    ...         ...  ...                 ...
# 2622128                 OOS      F  Other Race  ...            Self-Pay
# 2622129                 OOS      F  Other Race  ...            Self-Pay
# 2622130                 OOS      F  Other Race  ...            Self-Pay
# 2622131                 OOS      F  Other Race  ...                 NaN
# 2622132                 OOS      F  Other Race  ...                 NaN
#
#         Source_of_Payment_3 Attending_Provider_License_Number  \
# 0                       NaN                            3623.0
# 1                Blue Cross                          216951.0
# 2                  Self-Pay                            3076.0
# 3                  Self-Pay                          140796.0
# 4                  Self-Pay                          170254.0
# ...                     ...                               ...
# 2622128                 NaN                               NaN
# 2622129                 NaN                               NaN
# 2622130                 NaN                               NaN
# 2622131                 NaN                               NaN
# 2622132                 NaN                               NaN
#
#         Operating_Provider_License_Number  Other_Provider_License_Number  \
# 0                                     NaN                            NaN
# 1                                216951.0                            NaN
# 2                                     NaN                            NaN
# 3                                140796.0                       170254.0
# 4                                170254.0                       170254.0
# ...                                   ...                            ...
# 2622128                               NaN                            NaN
# 2622129                               NaN                            NaN
# 2622130                               NaN                            NaN
# 2622131                               NaN                            NaN
# 2622132                               NaN                            NaN
#
#          Birth_Weight Abortion_Edit_Indicator  Emergency_Department_Indicator  \
# 0                   0                       N                               Y
# 1                   0                       N                               Y
# 2                   0                       N                               N
# 3                   0                       N                               N
# 4                   0                       N                               N
# ...               ...                     ...                             ...
# 2622128             0                       Y                               Y
# 2622129             0                       Y                               N
# 2622130             0                       Y                               Y
# 2622131             0                       Y                               Y
# 2622132             0                       Y                               Y
#
#         Total_Charges  Total_Costs
# 0             4476.23      1672.65
# 1           148612.34     51414.70
# 2            16561.99      4032.49
# 3            13593.51      4947.81
# 4            31962.58     16988.33
# ...               ...          ...
# 2622128     230373.65     83223.46
# 2622129      20335.27      7677.97
# 2622130      27775.54      9819.99
# 2622131      11738.58      3295.21
# 2622132      10513.56      3856.01
#
# [2622133 rows x 38 columns]

# %%
#Created a new dataframe with only the required columns for Data Analysis.
hospital_data_analysis = modified_column_names[['index', 'Health_Service_Area', 'Hospital_County','Operating_Certificate_Number',
'Facility_ID', 'Facility_Name','Age_Group', 'Zip_Code_-_3_digits', 'Gender', 'Race', 'Ethnicity','Length_of_Stay',
'Type_of_Admission', 'Patient_Disposition','Discharge_Year', 'CCS_Diagnosis_Code', 'CCS_Diagnosis_Description',
'CCS_Procedure_Code', 'CCS_Procedure_Description', 'APR_DRG_Code','APR_DRG_Description', 'APR_MDC_Code', 'APR_MDC_Description',
'APR_Severity_of_Illness_Code', 'APR_Severity_of_Illness_Description','APR_Risk_of_Mortality', 'APR_Medical_Surgical_Description',
'Source_of_Payment_1','Attending_Provider_License_Number','Total_Charges', 'Total_Costs']]

display(hospital_data_analysis)
# Out:
#            index Health_Service_Area Hospital_County  \
# 0              0      Capital/Adiron          Albany
# 1              1      Capital/Adiron          Albany
# 2              2      Capital/Adiron          Albany
# 3              3      Capital/Adiron          Albany
# 4              4      Capital/Adiron          Albany
# ...          ...                 ...             ...
# 2622128  2622128                 NaN             NaN
# 2622129  2622129                 NaN             NaN
# 2622130  2622130                 NaN             NaN
# 2622131  2622131                 NaN             NaN
# 2622132  2622132                 NaN             NaN
#
#          Operating_Certificate_Number  Facility_ID  \
# 0                            101000.0          1.0
# 1                            101000.0          1.0
# 2                            101000.0          1.0
# 3                            101000.0          1.0
# 4                            101000.0          1.0
# ...                               ...          ...
# 2622128                           NaN          NaN
# 2622129                           NaN          NaN
# 2622130                           NaN          NaN
# 2622131                           NaN          NaN
# 2622132                           NaN          NaN
#
#                                     Facility_Name    Age_Group  \
# 0                  Albany Medical Center Hospital     18 to 29
# 1                  Albany Medical Center Hospital     50 to 69
# 2                  Albany Medical Center Hospital  70 or Older
# 3                  Albany Medical Center Hospital  70 or Older
# 4                  Albany Medical Center Hospital  70 or Older
# ...                                           ...          ...
# 2622128  Abortion Record - Facility Name Redacted     30 to 49
# 2622129  Abortion Record - Facility Name Redacted     30 to 49
# 2622130  Abortion Record - Facility Name Redacted     30 to 49
# 2622131  Abortion Record - Facility Name Redacted     30 to 49
# 2622132  Abortion Record - Facility Name Redacted     30 to 49
#
#         Zip_Code_-_3_digits Gender        Race  ... APR_MDC_Code  \
# 0                       NaN      F       White  ...            6
# 1                       NaN      M       White  ...           25
# 2                       NaN      M       White  ...            6
# 3                       NaN      F       White  ...           23
# 4                       NaN      F       White  ...            8
# ...                     ...    ...         ...  ...          ...
# 2622128                 OOS      F  Other Race  ...           14
# 2622129                 OOS      F  Other Race  ...           14
# 2622130                 OOS      F  Other Race  ...           14
# 2622131                 OOS      F  Other Race  ...           14
# 2622132                 OOS      F  Other Race  ...           14
#
#                                        APR_MDC_Description  \
# 0           Diseases and Disorders of the Digestive System
# 1                              Multiple Significant Trauma
# 2           Diseases and Disorders of the Digestive System
# 3        Rehabilitation, Aftercare, Other Factors Influ...
# 4        Diseases and Disorders of the Musculoskeletal ...
# ...                                                    ...
# 2622128           Pregnancy, Childbirth and the Puerperium
# 2622129           Pregnancy, Childbirth and the Puerperium
# 2622130           Pregnancy, Childbirth and the Puerperium
# 2622131           Pregnancy, Childbirth and the Puerperium
# 2622132           Pregnancy, Childbirth and the Puerperium
#
#         APR_Severity_of_Illness_Code APR_Severity_of_Illness_Description  \
# 0                                  1                               Minor
# 1                                  3                               Major
# 2                                  3                               Major
# 3                                  2                            Moderate
# 4                                  1                               Minor
# ...                              ...                                 ...
# 2622128                            3                               Major
# 2622129                            2                            Moderate
# 2622130                            1                               Minor
# 2622131                            1                               Minor
# 2622132                            2                            Moderate
#
#          APR_Risk_of_Mortality  APR_Medical_Surgical_Description  \
# 0                        Minor                           Medical
# 1                      Extreme                          Surgical
# 2                        Major                           Medical
# 3                        Minor                           Medical
# 4                        Minor                          Surgical
# ...                        ...                               ...
# 2622128                  Minor                          Surgical
# 2622129                  Minor                          Surgical
# 2622130                  Minor                          Surgical
# 2622131                  Minor                          Surgical
# 2622132                  Minor                          Surgical
#
#         Source_of_Payment_1  Attending_Provider_License_Number Total_Charges  \
# 0                Blue Cross                             3623.0       4476.23
# 1         Insurance Company                           216951.0     148612.34
# 2                  Medicare                             3076.0      16561.99
# 3                  Medicare                           140796.0      13593.51
# 4                  Medicare                           170254.0      31962.58
# ...                     ...                                ...           ...
# 2622128          Blue Cross                                NaN     230373.65
# 2622129          Blue Cross                                NaN      20335.27
# 2622130   Insurance Company                                NaN      27775.54
# 2622131            Self-Pay                                NaN      11738.58
# 2622132   Insurance Company                                NaN      10513.56
#
#          Total_Costs
# 0            1672.65
# 1           51414.70
# 2            4032.49
# 3            4947.81
# 4           16988.33
# ...              ...
# 2622128     83223.46
# 2622129      7677.97
# 2622130      9819.99
# 2622131      3295.21
# 2622132      3856.01
#
# [2622133 rows x 31 columns]

# %%
hospital_data_analysis.dtypes
# Out:
# index                                    int64
# Health_Service_Area                     object
# Hospital_County                         object
# Operating_Certificate_Number           float64
# Facility_ID                            float64
# Facility_Name                           object
# Age_Group                               object
# Zip_Code_-_3_digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length_of_Stay                          object
# Type_of_Admission                       object
# Patient_Disposition                     object
# Discharge_Year                           int64
# CCS_Diagnosis_Code                     float64
# CCS_Diagnosis_Description               object
# CCS_Procedure_Code                     float64
# CCS_Procedure_Description               object
# APR_DRG_Code                             int64
# APR_DRG_Description                     object
# APR_MDC_Code                             int64
# APR_MDC_Description                     object
# APR_Severity_of_Illness_Code             int64
# APR_Severity_of_Illness_Description     object
# APR_Risk_of_Mortality                   object
# APR_Medical_Surgical_Description        object
# Source_of_Payment_1                     object
# Attending_Provider_License_Number      float64
# Total_Charges                          float64
# Total_Costs                            float64
# dtype: object

# %%
#Converting the data type of Length of Stay column to Numeric from Object

df['Length_of_Stay'] = df['Length_of_Stay'].apply(lambda x: x.replace("'", "") if isinstance(x, str) and not x.isnumeric() else x)

# %%
df['Length_of_Stay'].unique()
# Out:
# array([  1.,  15.,   3.,   5.,   4.,   2.,   9.,  13.,  18.,   8.,   7.,
#          6.,  11.,  17.,  25.,  16.,  47.,  20.,  37.,  12.,  19.,  27.,
#         10.,  31.,  14.,  22.,  29.,  87., 103., 109.,  85.,  30.,  26.,
#         44.,  21.,  36.,  72.,  89.,  76.,  49.,  98., 105.,  69.,  45.,
#         32.,  57.,  24.,  39.,  81.,  33.,  28.,  23.,  77.,  88.,  63.,
#         55.,  41.,  61.,  53.,  38.,  51.,  40.,  35.,  59.,  46.,  50.,
#         92.,  64.,  34.,  73.,  60.,  67.,  68.,  97.,  80.,  82.,  71.,
#         95., 113., 118.,  54.,  91., 100., 115.,  90.,  42., 108.,  58.,
#         70.,  65.,  43.,  66.,  94.,  48.,  75., 112.,  52.,  78.,  62.,
#        106.,  84., 107.,  93., 104.,  56., 117.,  79., 116.,  83.,  74.,
#         96.,  86., 114., 110.,  99., 102., 101., 119., 111.])

# %%
#Convert the Data type of Length of Stay Column
df['Length_of_Stay'] = pd.to_numeric(df['Length_of_Stay'], errors = 'coerce')

#Drop the null values
df.dropna(subset=['Length_of_Stay'], inplace=True)

#Get the updated Data type
df['Length_of_Stay'].dtypes

#Display the values of the Length_of_Stay
display(df['Length_of_Stay'])
# Out:
# 0           1.0
# 1          15.0
# 2           3.0
# 3           5.0
# 4           4.0
#            ...
# 2622128    29.0
# 2622129     1.0
# 2622130     4.0
# 2622131     1.0
# 2622132     1.0
# Name: Length_of_Stay, Length: 2619918, dtype: float64

# %%
df_with_no_NaN_Values = df.dropna(subset=['index', 'Health_Service_Area', 'Hospital_County',
       'Operating_Certificate_Number', 'Facility_ID', 'Facility_Name',
       'Age_Group', 'Zip_Code_-_3_digits', 'Gender', 'Race', 'Ethnicity',
       'Length_of_Stay', 'Type_of_Admission', 'Patient_Disposition',
       'Discharge_Year', 'CCS_Diagnosis_Code', 'CCS_Diagnosis_Description',
       'CCS_Procedure_Code', 'CCS_Procedure_Description', 'APR_DRG_Code',
       'APR_DRG_Description', 'APR_MDC_Code', 'APR_MDC_Description',
       'APR_Severity_of_Illness_Code', 'APR_Severity_of_Illness_Description',
       'APR_Risk_of_Mortality', 'APR_Medical_Surgical_Description',
       'Source_of_Payment_1', 'Source_of_Payment_2', 'Source_of_Payment_3',
       'Attending_Provider_License_Number',
       'Operating_Provider_License_Number', 'Other_Provider_License_Number',
       'Birth_Weight', 'Abortion_Edit_Indicator',
       'Emergency_Department_Indicator', 'Total_Charges', 'Total_Costs'])

# %%
display(df)

# %%
columns_with_nan = df.columns[df.isna().any()].tolist()

# %%
columns_with_nan

# %%
# Assuming df is your DataFrame
selected_columns = ['index','CCS_Diagnosis_Code', 'CCS_Diagnosis_Description', 'CCS_Procedure_Code', 'CCS_Procedure_Description']

# Use the loc or iloc indexer to select only the specified columns
selected_df = df[selected_columns]

# Print the resulting DataFrame
display(selected_df)

# %%
unique_birth_weights = df['Birth_Weight'].unique()

display(unique_birth_weights)

# %%
df = df.drop([])

# %%
distinct_zip_code = df["Zip_Code_-_3_digits"].unique()

# %%
display(distinct_zip_code)

# %%
display(df["Zip_Code_-_3_digits"])

# %%
df["Zip_Code_-_3_digits"].isna().sum()

# %%
na_rows_zip_code = df[df["Zip_Code_-_3_digits"].isna()]

na_rows_info = na_rows_zip_code[["Health_Service_Area","Hospital_County"]]

display(na_rows_info)

# %%
county_albany = df[df["Hospital_County"]=="Albany"]


print(county_albany[["Hospital_County","Zip_Code_-_3_digits"]])

# %%
# Filter rows where "Hospital_County" is equal to "Albany" and "Zip_Code_-_3_digits" is equal to "100"
albany_with_zip_100 = df[(df["Hospital_County"] == "Albany") & (df["Zip_Code_-_3_digits"] == "100")]

# Check if there are any rows that match the condition
if not albany_with_zip_100.empty:
    print("Albany has a zip code of 100.")
else:
    print("Albany does not have a zip code of 100.")

# %%
display(albany_with_zip_100)

# %%
filtered_df = df.dropna(subset=['Health_Service_Area', 'Hospital_County', 'Zip_Code_-_3_digits'])

# Step 2: Create a dictionary to map ('Health_Service_Area', 'Hospital_County') to 'Zip_Code_-_3_digits'
zip_mapping = filtered_df.groupby(['Health_Service_Area', 'Hospital_County'])['Zip_Code_-_3_digits'].first().to_dict()

# Step 3: Fill missing 'Zip_Code_-_3_digits' values based on the mapping
df['Zip_Code_-_3_digits'] = df.apply(lambda row: zip_mapping.get((row['Health_Service_Area'], row['Hospital_County']), row['Zip_Code_-_3_digits']), axis=1)

# Display the updated DataFrame
display(df)

# %%
display(na_rows_zip_code)

# %%
na_rows_zip_code = df[df["Zip_Code_-_3_digits"].isna()]

# %%
# Step 1: Create a DataFrame with non-NaN values for 'Zip_Code_-_3_digits'
filtered_df = df.dropna(subset=['Zip_Code_-_3_digits'])

# Step 2: Create a dictionary to map 'Zip_Code_-_3_digits' to ('Health_Service_Area', 'Hospital_County')
zip_mapping = filtered_df.groupby('Zip_Code_-_3_digits')[['Health_Service_Area', 'Hospital_County']].first().to_dict(orient='index')

# Step 3: Fill missing 'Health_Service_Area' and 'Hospital_County' values based on the mapping
def fill_missing_values(row):
    zip_code = row['Zip_Code_-_3_digits']
    if pd.notna(zip_code) and zip_code in zip_mapping:
        mapping = zip_mapping[zip_code]
        row['Health_Service_Area'] = mapping['Health_Service_Area']
        row['Hospital_County'] = mapping['Hospital_County']
    return row

df = df.apply(fill_missing_values, axis=1)

# Display the updated DataFrame
display(df)

# %%
na_health_service_area_count = df['Health_Service_Area'].isna().sum()
na_hospital_county_count = df['Hospital_County'].isna().sum()
na_rows_zip_code = df["Zip_Code_-_3_digits"].isna().sum()
print("NaN count in 'Health_Service_Area':", na_health_service_area_count)
print("NaN count in 'Hospital_County':", na_hospital_county_count)
print("NaN count in 'Zip_Code_-_3_digits':",na_rows_zip_code)

# %%
oos_rows_zip_code = df[df["Zip_Code_-_3_digits"] == "OOS"].shape[0]

# %%
display(oos_rows_zip_code)

# %%
# Filter rows where both 'Health_Service_Area' and 'Hospital_County' are NaN
na_rows = df[df['Health_Service_Area'].isna() & df['Hospital_County'].isna()]

# Display the filtered DataFrame
print(na_rows[['Health_Service_Area', 'Hospital_County']])

# %%
both_na_mask = df['Health_Service_Area'].isna() & df['Hospital_County'].isna()

# Filter the DataFrame based on the mask
na_rows = df[both_na_mask]

# Check if there are any rows where both columns have NaN values
if not na_rows.empty:
    # Perform your desired action for rows where both columns have NaN values
    # For example, you can display these rows or perform further processing
    print("Rows where both 'Health_Service_Area' and 'Hospital_County' have NaN values:")
    display(na_rows)
else:
    print("No rows found where both 'Health_Service_Area' and 'Hospital_County' have NaN values.")

# %%
# Iterate through rows of the DataFrame
for index, row in df.iterrows():
    zip_code = row['Zip_Code_-_3_digits']
    health_service_area = row['Health_Service_Area']
    hospital_county = row['Hospital_County']
    
    # Check if 'Zip_Code_-_3_digits' has a value and 'Health_Service_Area' is "None"
    if pd.notna(zip_code) and health_service_area == "None":
        # Find a matching row with the same 'Zip_Code_-_3_digits'
        matching_row = df[df['Zip_Code_-_3_digits'] == zip_code].iloc[0]
        
        # Get the values from the matching row and update the current row
        df.at[index, 'Health_Service_Area'] = matching_row['Health_Service_Area']
        df.at[index, 'Hospital_County'] = matching_row['Hospital_County']

# Display the updated DataFrame
display(df)

# %%
na_health_service_area_count = df['Health_Service_Area'].isna().sum()
na_hospital_county_count = df['Hospital_County'].isna().sum()
na_rows_zip_code = df["Zip_Code_-_3_digits"].isna().sum()
print("NaN count in 'Health_Service_Area':", na_health_service_area_count)
print("NaN count in 'Hospital_County':", na_hospital_county_count)
print("NaN count in 'Zip_Code_-_3_digits':",na_rows_zip_code)

# %%
none_rows_health_service_area = df[df["Health_Service_Area"] == "None"]
display(none_rows_health_service_area)

# %%
none_rows_hospital_county = df[df["Hospital_County"] == "None"].shape[0]
display(none_rows_hospital_county)

# %%
display(df)

# %%
df[df["Health_Service_Area"].isna()]

# %%
result_df = df[(df["Zip_Code_-_3_digits"] == 106) & (~df["Health_Service_Area"].isna()) & (~df["Hospital_County"].isna())]

display(result_df)

# %%
health_service_area_dtype = df["Health_Service_Area"].dtype
print(health_service_area_dtype)

# %%
df["Health_Service_Area"] = df["Health_Service_Area"].astype(pd.StringDtype())
health_service_dtype = df["Health_Service_Area"].dtype
print(health_service_area_dtype)
